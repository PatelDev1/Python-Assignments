# %% [markdown]
# **01:- What is List? How will you reverse a list?**
#
# **LIST DEFINE :- Lists are used to store multiple items in a single variable.
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.**
#
# **Python List reverse()
# Python List reverse() is an inbuilt method in the Python programming language that reverses objects of the List in place i.e. it doesn’t use any extra space but it just modifies the original list.**
#
# **REVERSE A LIST()
# Reversing a list in-place with the list.reverse() method
# Using the “[::-1]” list slicing trick to create a reversed copy
# Creating a reverse iterator with the reversed() built-in function**

# %% [markdown]
# **02 :- How will you remove last object from a list?**

# %%
list_of_vowels = ['a','e','i','o','u']
list_of_vowels.pop()

print(list_of_vowels)
# Out:
# ['a', 'e', 'i', 'o']

# %% [markdown]
# **03 :- Suppose list1 is [2, 33, 222, 14, and 25], what is list1 [-1] ?**
#
# **ANSWER :- Explanation: -1 corresponds to the last index in the list.**

# %% [markdown]
# **04 :- Differentiate between append () and extend () methods?**
#
# **extend()**
#
# **Adds multiple elements to a list.**
#
# **Length increases by the number of elements added.**
#
# **Time complexity is O(n), with n being a number of list elements.**
#
# **append()**
#
# **Adds the input as a single element to a list.**
#
# **Length increases by 1.**
#
# **Time complexity O(1) or constant.**

# %% [markdown]
# **05 :- Write a Python function to get the largest number, smallest num and sum
# of all from a list.**

# %%
n=int(input("ENTER THE TOTAL NO OF ELEMENT YOU WANT INSIDE YOUR LIST : "))
l=[]

for i in range (n):
    ele=int(input("ENTER THE ELEMENT : "))
    l.append(ele)
    print("MY LIST",l)
    
    sort_list=l.sort()
    print("SORTED LIST : ",l)
    
    minimum_ele=l[0]
    print("MINIMUM ELMENT : ",minimum_ele)
    
    maximum_ele=l[-1]
    print("MAXIMUM ELEMENT : ",maximum_ele)

# %% [markdown]
# **06 :- How will you compare two lists?**
#
# **DEFINE :- TWO LISTS CAN BE COMPARED WITH THE COMPARSION OPERATOR OF PYTHON**
#
# **I.E :- <, <=, >, >=, ==, !=,**
#
# **PYTHON INTERNALLY COMPARES INDIVIDUAL ELEMENTS OF LIST IN LEXICOGRAPHICAL ORDER**

# %%
#PROGRAM TO COMPARE 2 LISTS
def compare(l1,l2):
    
    list1.sort()
    list2.sort()
    
    list1=[2,3,4,5]
    list2=[5,4,2,3]
    
    print("COMPARSION",compare(list1,list2))
    
    if(list1==list2):
        print("EQUAL LIST")
    else:
        print("NOT EQUAL LIST")

# %% [markdown]
# **07:- Write a Python program to count the number of strings where the string**
#
# **length is 2 or more and the first and last character are same from a given**
#
# **list of strings.**

# %%
def match_words(words):
  ctr = 0

  for word in words:
    if len(word) > 1 and word[0] == word[-1]:
      ctr += 1
  return ctr

print(match_words(['abc', 'xyz', 'aba', '1221']))
# Out:
# 2

# %% [markdown]
# **O8:- Write a Python function that checks whether a passed string is palindrome**

# %%
def isPalindrome(string):
	left_pos = 0
	right_pos = len(string) - 1
	
	while right_pos >= left_pos:
		if not string[left_pos] == string[right_pos]:
			return False
		left_pos += 1
		right_pos -= 1
	return True
print(isPalindrome('aza'))
# Out:
# True

# %% [markdown]
# ** O9:- How do you perform pattern matching in Python? Explain **

# %%
# Importing re module
import re

#Intializing text and pattern
pattern=["Life","journey"]
s1="Life is a journey not a destination"

#Interating over the text to search for pattern
for i in pattern:
    print ("Searching ",i)
    if(re.search(i))

# %% [markdown]
# 10 :- Write a Python program to convert a list of characters into a string

# %% [markdown]
# **Actual String: Ask Python**
#
# **Type of string:  <class 'str'>**
#
# **String converted to list :**
#
# **['A' ,  's' ,  'k' ,  'P' ,  'y' ,  't' ,  'h' ,  'o' ,  'n']**

# %% [markdown]
# **11 :-  Write a Python program to select an item randomly from a list**
#
# **from random import choice**
#
# **def random_element(lst):**
#
# **return choice(lst)**
#
# **print(random_element([2, 3, 4, 7, 9, 11, 15]))**

# %% [markdown]
# **12 :- write a python program to find the second smallest number in a list**
#
# **# Python prog to illustrate the following in a list**

# %% [markdown]
# ****

# %% [markdown]
# **13:- Write a python program to get unique values from a list**

# %%
my_list = [10, 20, 30, 40, 20, 50, 60, 40]
print("Original List : ",my_list)
my_set = set(my_list)
my_new_list = list(my_set)
print("List of unique numbers : ",my_new_list)
# Out:
# Original List :  [10, 20, 30, 40, 20, 50, 60, 40]
# List of unique numbers :  [40, 10, 50, 20, 60, 30]

# %% [markdown]
# **14 :- Write a Python program to check whether a list contains a sub list**

# %%
def is_Sublist(l, s):
	sub_set = False
	if s == []:
		sub_set = True
	elif s == l:
		sub_set = True
	elif len(s) > len(l):
		sub_set = False

	else:
		for i in range(len(l)):
			if l[i] == s[0]:
				n = 1
				while (n < len(s)) and (l[i+n] == s[n]):
					n += 1
				
				if n == len(s):
					sub_set = True

	return sub_set

a = [2,4,3,5,7]
b = [4,3]
c = [3,7]
print(is_Sublist(a, b))
print(is_Sublist(a, c))
# Out:
# True
# False

# %% [markdown]
# **15 :- Write a Python program to split a list into different variables**

# %%
color = [("Black", "#000000", "rgb(0, 0, 0)"), ("Red", "#FF0000", "rgb(255, 0, 0)"),
         ("Yellow", "#FFFF00", "rgb(255, 255, 0)")]
var1, var2, var3 = color
print(var1)
print(var2)
print(var3)
# Out:
# ('Black', '#000000', 'rgb(0, 0, 0)')
# ('Red', '#FF0000', 'rgb(255, 0, 0)')
# ('Yellow', '#FFFF00', 'rgb(255, 255, 0)')

# %% [markdown]
# **16 :- What is tuple? Difference between list and tuple**
#
# **Python Lists**
#
# **1 List are mutable**
#
# **2 Iterations are time-consuming**
#
# **3 Inserting and deleting items is easier with a list**
#
# **4 Lists consume more memory**
#
# **5 Lists have several built-in methods**
#
# **6 A unexpected change or error is more likely to occur in a list**
#
#
# **Python tuples**
#
# **1 Tuples are immutable**
#
# **2 Iterations are comparatively Faster**
#
# **3 Accessing the elements is best accomplished with a tuple data type**
#
# **4 Tuple consumes less than the list**
#
# **5 A tuple does not have many built-in methods because of immutability**
#
# **6 In a tuple, changes and errors don't usually occur because of immutability**

# %% [markdown]
# **17 :-  Write a Python program to create a tuple with different data types**

# %%
#Create a tuple with different data types
tuplex = ("tuple", False, 3.2, 1)
print(tuplex)
# Out:
# ('tuple', False, 3.2, 1)

# %% [markdown]
# **18 :-  Write a Python program to create a tuple with numbers**

# %%
# Example

nTuple = 22,
print("Tuple Items = ", nTuple)

numTuple = (10, 20, 40, 60, 80, 100)
print("Tuple Items = ", numTuple)
# Out:
# Tuple Items =  (22,)
# Tuple Items =  (10, 20, 40, 60, 80, 100)

# %% [markdown]
# **19 :-  Write a Python program to convert a tuple to a string**

# %%
# Python3 code to convert a tuple
# into a string using a for loop
 
 
def convertTuple(tup):
        # initialize an empty string
    str = ''
    for item in tup:
        str = str + item
    return str
 
 
# Driver code
tuple = ('g', 'e', 'e', 'k', 's')
str = convertTuple(tuple)
print(str)
# Out:
# geeks

# %% [markdown]
# **20 :-  Write a Python program to check whether an element exists within a
# tuple**

# %%
tuplex = ("w", 3, "r", "e", "s", "o", "u", "r", "c", "e")
print("r" in tuplex)
print(5 in tuplex)
# Out:
# True
# False

# %% [markdown]
# **21 :-  Write a Python program to find the length of a tuple**

# %%
#create a tuple
tuplex = tuple("w3resource")
print(tuplex)
#use the len() function to known the length of tuple
print(len(tuplex))

# %% [markdown]
# **22 :-  Write a Python program to convert a list to a tuple**

# %%
lis= [10,20,30,40,50]
print(lis)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# **23 :-  Write a Python program to reverse a tuple**

# %%
#create a tuple
x = ("w3resource")
# Reversed the tuple
y = reversed(x)
print(tuple(y))
#create another tuple
x = (5, 10, 15, 20)
# Reversed the tuple
y = reversed(x)
print(tuple(y))

# %% [markdown]
# **24 :-  Write a Python program to replace last value of tuples in a list**

# %%
l = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
print([t[:-1] + (100,) for t in l])
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %% [markdown]
# **25 :-  Write a Python program to find the repeated items of a tuple**

# %%
#create a tuple
tuplex = 2, 4, 5, 6, 2, 3, 4, 4, 7 
print(tuplex)
#return the number of times it appears in the tuple.
count = tuplex.count(4)
print(count)
# Out:
# (2, 4, 5, 6, 2, 3, 4, 4, 7)
# 3

# %% [markdown]
# **26 :- Write a Python program to remove an empty tuple(s) from a list of tuples**

# %%
L = [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')]
L = [t for t in L if t]
print(L)
# Out:
# [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %% [markdown]
# **27 :-  Write a Python program to unzip a list of tuples into individual lists**

# %%
#create a tuple
l = [(1,2), (3,4), (8,9)]
print(list(zip(*l)))
# Out:
# [(1, 3, 8), (2, 4, 9)]

# %% [markdown]
# **28 :-  Write a Python program to convert a list of tuples into a dictionary**

# %%
# Python code to convert into dictionary

def Convert(tup, di):
	for a, b in tup:
		di.setdefault(a, []).append(b)
	return di
	
# Driver Code
tups = [("akash", 10), ("gaurav", 12), ("anand", 14),
	("suraj", 20), ("akhil", 25), ("ashish", 30)]
dictionary = {}
print (Convert(tups, dictionary))
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %% [markdown]
# **29 :-  How will you create a dictionary using tuples in python**

# %%
# input tuple
inputTuple = ((5, "TutorialsPoint"), (6, "Python"), (7, "Codes"))
print("The input Tuple:", inputTuple)

# Here we are iterating through each element (pairs) of the tuple using dictionary comprehension and converting it to the dictionary
resultDictionary = dict((x, y) for x, y in inputTuple)
print("The result dictionary:", resultDictionary)
# Out:
# The input Tuple: ((5, 'TutorialsPoint'), (6, 'Python'), (7, 'Codes'))
# The result dictionary: {5: 'TutorialsPoint', 6: 'Python', 7: 'Codes'}

# %% [markdown]
# **30 :-  Write a Python script to sort (ascending and descending) a dictionary by value**

# %%
import operator
d = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
print('Original dictionary : ',d)
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
print('Dictionary in ascending order by value : ',sorted_d)
sorted_d = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))
print('Dictionary in descending order by value : ',sorted_d)
# Out:
# Original dictionary :  {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
# Dictionary in ascending order by value :  [(0, 0), (2, 1), (1, 2), (4, 3), (3, 4)]
# Dictionary in descending order by value :  {3: 4, 4: 3, 1: 2, 2: 1, 0: 0}

# %% [markdown]
# **31 :-  Write a Python script to concatenate following dictionaries to create a new one**

# %%
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
dic4 = {}
for d in (dic1, dic2, dic3): dic4.update(d)
print(dic4)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# **32 :-Write a Python script to check if a given key already exists in a dictonary**

# %%
d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
def is_key_present(x):
  if x in d:
      print('Key is present in the dictionary')
  else:
      print('Key is not present in the dictionary')
is_key_present(5)
is_key_present(9)
# Out:
# Key is present in the dictionary
# Key is not present in the dictionary

# %% [markdown]
# **33 :- How Do You Traverse Through A Dictionary Object In Python**

# %%
 # Python 2.7
 a_dict = {'color': 'blue', 'fruit': 'apple', 'pet': 'dog'}
 a_dict
{'color': 'blue', 'pet': 'dog', 'fruit': 'apple'}
 a_dict
{'color': 'blue', 'pet': 'dog', 'fruit': 'apple'}
# Out:
# {'color': 'blue', 'pet': 'dog', 'fruit': 'apple'}

# %% [markdown]
# **34 :-  How Do You Check The Presence Of A Key In A Dictionary**

# %%
dictExample = {'Apples': 10,'Bananas': 20,'Chocolate': 30}

keyToFind = 'Apples'

if keyToFind in dictExample:

  print("The given key exists in the dictionary")

else:

  print("The given key does not exist in the dictionary")

  

keyToFind2 = 'Orange'



if keyToFind2 in dictExample:

  print("The given key exists in the dictionary")

else:

  print("The given key does not exist in the dictionary")
# Out:
# The given key exists in the dictionary
# The given key does not exist in the dictionary

# %% [markdown]
# **35 :-  Write a Python script to merge two Python dictionaries**

# %%
d1 = {'a': 100, 'b': 200}
d2 = {'x': 300, 'y': 200}
d = d1.copy()
d.update(d2)
print(d)
# Out:
# {'a': 100, 'b': 200, 'x': 300, 'y': 200}

# %% [markdown]
# **36 :-  Write a Python program to map two lists into a dictionary**

# %%
keys = ['red', 'green', 'blue']
values = ['#FF0000','#008000', '#0000FF']
color_dictionary = dict(zip(keys, values))
print(color_dictionary)
# Out:
# {'red': '#FF0000', 'green': '#008000', 'blue': '#0000FF'}

# %% [markdown]
# **37 :- Write a Python program to print all unique values in a dictionary**

# %%
L = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
print("Original List: ",L)
u_value = set( val for dic in L for val in dic.values())
print("Unique Values: ",u_value)
# Out:
# Original List:  [{'V': 'S001'}, {'V': 'S002'}, {'VI': 'S001'}, {'VI': 'S005'}, {'VII': 'S005'}, {'V': 'S009'}, {'VIII': 'S007'}]
# Unique Values:  {'S001', 'S009', 'S007', 'S005', 'S002'}

# %% [markdown]
# **38 :-  Write a Python program to find the highest 3 values in a dictionary**

# %%
# Python program to demonstrate
# finding 3 highest values in a Dictionary

from collections import Counter

# Initial Dictionary
my_dict = {'A': 67, 'B': 23, 'C': 45,
		'D': 56, 'E': 12, 'F': 69}

k = Counter(my_dict)

# Finding 3 highest values
high = k.most_common(3)

print("Initial Dictionary:")
print(my_dict, "\n")


print("Dictionary with 3 highest values:")
print("Keys: Values")

for i in high:
	print(i[0]," :",i[1]," ")
# Out:
# Initial Dictionary:
# {'A': 67, 'B': 23, 'C': 45, 'D': 56, 'E': 12, 'F': 69}
#
# Dictionary with 3 highest values:
# Keys: Values
# F  : 69
# A  : 67
# D  : 56

# %% [markdown]
# **39 :-  How can you pick a random item from a list or tuple**

# %%
# importing random module
import random
# input tuple
inputTuple = (30, 10, "TutorialsPoint", 20, "python", "code")
# printing the given input tuple
print("The given input tuple: ", inputTuple)
# generating a random item from the tuple using random.choice() method
randomItem = random.choice(inputTuple)
print("The generated random tuple item = ", randomItem)
# Out:
# The given input tuple:  (30, 10, 'TutorialsPoint', 20, 'python', 'code')
# The generated random tuple item =  python

# %% [markdown]
# **40 :-  How can you pick a random item from a range**

# %%
import random

number_list = [111, 222, 333, 444, 555]
# random item from list
print(random.choice(number_list))
# Output 222
# Out:
# 444

# %% [markdown]
# **41 :-  How can you get a random number in python**

# %%
# Program to generate a random number between 0 and 9

# importing the random module
import random

print(random.randint(0,9))
# Out:
# 0

# %% [markdown]
# **42 :-  How will you set the starting value in generating random numbers**

# %%
import random as rd

rnum = rd.random()

print(rnum)
# Out:
# 0.7351399728816923

# %% [markdown]
# **43 :- How will you randomizes the items of a list in place**

# %%
import random

list = [20, 16, 10, 5];
random.shuffle(list)
print ("Reshuffled list : ",  list)

random.shuffle(list)
print ("Reshuffled list : ",  list)
# Out:
# Reshuffled list :  [16, 20, 5, 10]
# Reshuffled list :  [10, 5, 16, 20]

# %% [markdown]
# **44 :- Write a Python program to read a random line from a file**

# %%
import random

def random_line(afile):
    line = next(afile)
    for num, aline in enumerate(afile, 2):
        if random.randrange(num):
            continue
        line = aline
    return line

# %% [markdown]
# **45 :-  Write a Python program to calculate the area of a trapezoid**

# %%
base_1 = 5
base_2 = 6
height = float(input("Height of trapezoid: "))
base_1 = float(input('Base one value: '))
base_2 = float(input('Base two value: '))
area = ((base_1 + base_2) / 2) * height
print("Area is:", area)
# Out:
# Height of trapezoid: 6
# Base one value: 10
# Base two value: 5
# Area is: 45.0

# %% [markdown]
# **46 :- Write a Python program to calculate the area of a parallelogram**

# %%
base = float(input('Length of base: '))
height = float(input('Measurement of height: '))
area = base * height
print("Area is: ", area)
# Out:
# Length of base: 5
# Measurement of height: 6
# Area is:  30.0

# %% [markdown]
# **47 :- Write a Python program to calculate surface volume and area of a cylinder**

# %%
pi=22/7
height = float(input('Height of cylinder: '))
radian = float(input('Radius of cylinder: '))
volume = pi * radian * radian * height
sur_area = ((2*pi*radian) * height) + ((pi*radian**2)*2)
print("Volume is: ", volume)
print("Surface Area is: ", sur_area)
# Out:
# Height of cylinder: 4
# Radius of cylinder: 6
# Volume is:  452.57142857142856
# Surface Area is:  377.1428571428571
